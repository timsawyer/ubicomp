# %%
print("hello world")
# Out:
# hello world

# %%
l = 1,2,3,4,5

# %%
print(l)
# Out:
# (1, 2, 3, 4, 5)

# %%
import matplotlib.pyplot as plt
fig, axes = plt.subplots()
axes.plot(l)

# %%
import matplotlib.pyplot as plt
fig2, axes2 = plt.subplots()

mapNametoAge = dict()
mapNametoAge["Susan"] = 5
mapNametoAge["Bob"] = 40
mapNametoAge["Garth"] = 15
mapNametoAge["Leo"] = 35
mapNametoAge["Cindy"] = 9

axes2.plot(mapNametoAge.values())
